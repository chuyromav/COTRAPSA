# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/Users/Laura/Desktop/Chuy/COTRAPSA/ANALISIS FACTURAS/datos/Facturas.xlsx')

# %%
df.head()
# Out:
#                                    Nombre    Estatus Fecha de elaborac  \
# 0           CAMIONERA CATOSA S.A. DE C.V.  Cancelada        2016-09-20
# 1                     ELVIA AVILES BATREZ  Cancelada        2016-11-10
# 2  SERVICIOS TRACTOMOTRICES, S.A. DE C.V.  Cancelada        2017-10-05
# 3  SERVICIOS TRACTOMOTRICES, S.A. DE C.V.  Cancelada        2017-10-05
# 4                  NITROPET, S.A. DE C.V.  Cancelada        2019-04-12
#
#   Fecha de pago  Subtotal  Moned  Importe total Metodo de pago
# 0    2016-09-27  45030.00    2.0       52234.80              2
# 1    2016-11-10  54310.35    1.0       63000.01            NaN
# 2    2017-10-13   2662.00    1.0        3087.92              3
# 3    2017-10-13   2662.00    1.0        3087.92              3
# 4    2019-06-11  17857.00    1.0       20714.12            PUE

# %%
df.shape
# Out:
# (1909, 8)

# %%
df=df[df.Estatus=='Emitida']

# %%
df.head()
# Out:
#                                  Nombre  Estatus Fecha de elaborac  \
# 6                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 7                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 8                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 9         OMAR RODRIGO BRAMBILA TAMARIZ  Emitida        2016-01-05
# 10  STOUGHTON REFACCIONES Y SERVICIO ME  Emitida        2016-01-06
#
#    Fecha de pago  Subtotal  Moned  Importe total         Metodo de pago
# 6     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 7     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 8     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 9     2016-02-04  15910.00    1.0       18455.60  TRANSFERENCIA ELECTRO
# 10    2016-01-14   2255.50    2.0        2616.38                    NaN

# %%
df.columns
# Out:
# Index([u'Nombre', u'Estatus', u'Fecha de elaborac', u'Fecha de pago',
#        u'Subtotal', u'Moned', u'Importe total', u'Metodo de pago'],
#       dtype='object')

# %%
df['Fecha de pago'][6]
# Out:
# Timestamp('2016-02-04 00:00:00')

# %%
df['ano-mes']=df['Fecha de pago'].map(lambda x:x.strftime('%Y%m'))

# %%
df['ano']=df['Fecha de pago'].map(lambda x:x.strftime('%Y'))

# %%
df['mes']=df['Fecha de pago'].map(lambda x:x.strftime('%m'))

# %%
df.ano.value_counts(normalize=True)
# Out:
# 2019    0.398164
# 2018    0.236948
# 2017    0.203098
# 2016    0.153758
# 2020    0.008032
# Name: ano, dtype: float64

# %%
df.head()
# Out:
#                                  Nombre  Estatus Fecha de elaborac  \
# 6                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 7                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 8                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 9         OMAR RODRIGO BRAMBILA TAMARIZ  Emitida        2016-01-05
# 10  STOUGHTON REFACCIONES Y SERVICIO ME  Emitida        2016-01-06
#
#    Fecha de pago  Subtotal  Moned  Importe total         Metodo de pago  \
# 6     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 7     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 8     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 9     2016-02-04  15910.00    1.0       18455.60  TRANSFERENCIA ELECTRO
# 10    2016-01-14   2255.50    2.0        2616.38                    NaN
#
#    ano-mes   ano mes
# 6   201602  2016  02
# 7   201602  2016  02
# 8   201602  2016  02
# 9   201602  2016  02
# ...

# %%
df_pesos=df[df.Moned==1.0]
df_dolar=df[df.Moned==2.0]

# %%
df_pesos['Importe_pesos']=df_pesos['Importe total']
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pesos.head()
# Out:
#                            Nombre  Estatus Fecha de elaborac Fecha de pago  \
# 6             BIMBO, S.A. DE C.V.  Emitida        2016-01-05    2016-02-04
# 7             BIMBO, S.A. DE C.V.  Emitida        2016-01-05    2016-02-04
# 8             BIMBO, S.A. DE C.V.  Emitida        2016-01-05    2016-02-04
# 9   OMAR RODRIGO BRAMBILA TAMARIZ  Emitida        2016-01-05    2016-02-04
# 11  OMAR RODRIGO BRAMBILA TAMARIZ  Emitida        2016-01-08    2016-02-07
#
#     Subtotal  Moned  Importe total         Metodo de pago ano-mes   ano mes  \
# 6   79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO  201602  2016  02
# 7   79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO  201602  2016  02
# 8   79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO  201602  2016  02
# 9   15910.00    1.0       18455.60  TRANSFERENCIA ELECTRO  201602  2016  02
# 11   8749.00    1.0       10148.84  TRANSFERENCIA ELECTRO  201602  2016  02
#
#     Importe_pesos
# 6        92394.28
# 7        92394.28
# ...

# %%
df_dolar_2016=df_dolar[df_dolar.ano=='2016']
df_dolar_2017=df_dolar[df_dolar.ano=='2017']
df_dolar_2018=df_dolar[df_dolar.ano=='2018']
df_dolar_2019=df_dolar[df_dolar.ano=='2019']

# %%
df_dolar_2016['Importe_pesos']=df_dolar_2016['Importe total']*18.6886
df_dolar_2016['Importe_pesos']=df_dolar_2016['Importe_pesos'].map(lambda x:format(x , '.4f'))

df_dolar_2017['Importe_pesos']=df_dolar_2017['Importe total']*18.9066
df_dolar_2017['Importe_pesos']=df_dolar_2017['Importe_pesos'].map(lambda x:format(x , '.4f'))

df_dolar_2018['Importe_pesos']=df_dolar_2018['Importe total']*19.2373
df_dolar_2018['Importe_pesos']=df_dolar_2018['Importe_pesos'].map(lambda x:format(x , '.4f'))

df_dolar_2019['Importe_pesos']=df_dolar_2019['Importe total']*19.2726
df_dolar_2019['Importe_pesos']=df_dolar_2019['Importe_pesos'].map(lambda x:format(x , '.4f'))
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_dolar_2017
# Out:
#                                         Nombre  Estatus Fecha de elaborac  \
# 296  UTILITY TRAILERS DE MEXICO,  S.A.P.I.  DE  Emitida        2016-12-08
# 297  UTILITY TRAILERS DE MEXICO,  S.A.P.I.  DE  Emitida        2016-12-08
# 325              CAMIONERA CATOSA S.A. DE C.V.  Emitida        2017-01-03
# 326       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-03
# 327       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-03
# 328       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-03
# 329       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-03
# 330       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-10
# 331       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-10
# 332       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-11
# 335       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-12
# 336       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2017-01-12
# ...

# %%
facturas=pd.concat([df_dolar_2016, df_dolar_2017,df_dolar_2018,df_dolar_2019,df_pesos], axis=0)

# %%
facturas[['mes','Importe total','Importe_pesos']].groupby('mes').sum()
# Out:
#      Importe total
# mes
# 01      1946001.39
# 02      3191951.09
# 03      2313364.92
# 04      3039838.96
# 05      3143339.38
# 06      3033308.29
# 07      3850094.53
# 08      4336924.55
# 09      5478473.40
# 10      3165573.88
# 11      2963561.90
# 12      3204486.99

# %%
facturas.head()
# Out:
#                                        Nombre  Estatus Fecha de elaborac  \
# 10        STOUGHTON REFACCIONES Y SERVICIO ME  Emitida        2016-01-06
# 18       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2016-01-21
# 19       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2016-01-22
# 23  UTILITY TRAILERS DE MEXICO,  S.A.P.I.  DE  Emitida        2016-01-26
# 25       MUNDO GLOBAL DE REMOLQUES, S.A. DE C  Emitida        2016-01-27
#
#    Fecha de pago   Subtotal  Moned  Importe total         Metodo de pago  \
# 10    2016-01-14    2255.50    2.0        2616.38                    NaN
# 18    2016-01-29  109714.08    2.0      127268.34  TRANSFERENCIA ELECTRO
# 19    2016-01-30   22180.89    2.0       25729.81  TRANSFERENCIA ELECTRO
# 23    2016-03-26    5252.55    2.0        6092.96  TRANSFERENCIA  ELECTR
# 25    2016-02-04   20596.46    2.0       23891.94  TRANSFERENCIA ELECTRO
#
#    ano-mes   ano mes Importe_pesos
# 10  201601  2016  01    48896.4793
# ...

# %%
df.head()
# Out:
#                                  Nombre  Estatus Fecha de elaborac  \
# 6                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 7                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 8                   BIMBO, S.A. DE C.V.  Emitida        2016-01-05
# 9         OMAR RODRIGO BRAMBILA TAMARIZ  Emitida        2016-01-05
# 10  STOUGHTON REFACCIONES Y SERVICIO ME  Emitida        2016-01-06
#
#    Fecha de pago  Subtotal  Moned  Importe total         Metodo de pago  \
# 6     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 7     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 8     2016-02-04  79650.24    1.0       92394.28  TRANSFERENCIA ELECTRO
# 9     2016-02-04  15910.00    1.0       18455.60  TRANSFERENCIA ELECTRO
# 10    2016-01-14   2255.50    2.0        2616.38                    NaN
#
#    ano-mes   ano mes
# 6   201602  2016  02
# 7   201602  2016  02
# 8   201602  2016  02
# 9   201602  2016  02
# ...

# %%
Importe_Cliente=df[['Nombre','Importe total']].groupby('Nombre').sum()

# %%
df.columns
# Out:
# Index([u'Nombre', u'Estatus', u'Fecha de elaborac', u'Fecha de pago',
#        u'Subtotal', u'Moned', u'Importe total', u'Metodo de pago', u'ano-mes',
#        u'ano', u'mes'],
#       dtype='object')

# %%
Importe_ano=df[['ano','Importe total']].groupby('ano').sum()

# %%
Importe_ano_mes=df[['ano-mes','Importe total']].groupby('ano-mes').sum()

# %%
Importe_mes=df[['mes','Importe total']].groupby('mes').sum()

# %%
df['ano'].value_counts()
# Out:
# 2019    694
# 2018    413
# 2017    354
# 2016    268
# 2020     14
# Name: ano, dtype: int64

# %%
Importe_ano
# Out:
#       Importe total
# ano
# 2016     6524997.04
# 2017     8293438.62
# 2018    10549919.51
# 2019    14083109.19
# 2020      215454.92

# %%
BIMBO=df[df['Nombre']=='BIMBO, S.A. DE C.V.']

BARCEL=df[df['Nombre']=='BARCEL S.A. DE C.V.']

ALPURA=df[df['Nombre']=='TRANSPORTADORA ALPURA S.A.P.I. DE C.V.']

FACTURAS_SIN_SERVICIOS=df[df['Nombre'].isin([u'AIRIBUZ S.A. DE C.V-', u'ALEJANDRO CHAVEZ GONZALEZ',
       u'AMERICAN SMARTRUCKS, S.A. DE C.V.', u'ANGEL FLORES ARAUJO',
       u'ARTÍCULOS INDUSTRIALES VADE, S.DE R.L.', u'ARVAL, S.A.',
       u'BRANDES INTERNATIONAL CO.',
       u'BULKMATIC DE MEXICO, S. DE R.L. DE C.V.',
       u'CAMIONERA CATOSA S.A. DE C.V.', u'CESAR SUAREZ ALCANTARA',
       u'COMERCIALIZADORA DE REMOLQUES COR',
       u'COMERCIALIZADORA SUDIMEX, S. DE R. L.',
       u'CORPORATIVO MACRO DIESEL, S.A. DE C.V.',
       u'DE LA LUZ TRAILERS S.A. DE C.V.', u'ELVIA AVILES BATREZ',
       u'ENTORNO INDUSTRIAL, S.A. DE C.V.',
       u'ESPECIALIZADOS EN REMOLQUES Y CARRO', u'EXA INDUSTRIAL S.A. DE C.V.',
       u'FLETES HESA, S.A. DE C.V.', u'FRUEHAUF DE MEXICO, S.A. DE C.V.',
       u'GERARDO MARTINEZ SEGURA', u'GRANPORTUARIA SERVICIOS DEDICADOS S',
       u'GRIMALDO HERNANDEZ OLGA LYDIA',
       u'GRUPO INDUSTRIAL DAVASA, S.A. DE C.V.',
       u'INDUSTRIAS MAVAEN S.A. DE C.V.',
       u'INDUSTRIAS Y MANUFACTURAS MUÑOZ, S.',
       u'INSPECCION Y CRIOGENIA ICSA, S.A. DE C.V', u'JEBOL MEXICO SA DE C V',
       u'MARCO ANTONIO HUITRON FUENTES', u'MARIBEL BANDA ALONSO',
       u'MARTHA ELENA MENDOZA MEDINA', u'MECANICA TEK S.A. DE C.V.',
       u'METRICA MOVIL S.A. DE C.V.', u'MUNDO GLOBAL DE REMOLQUES, S.A. DE C',
       u'NITROPET, S.A. DE C.V.', u'OMAR RODRIGO BRAMBILA TAMARIZ',
       u'OPERBUS, S.A. DE C.V.', u'PAULO CESAR RUIZ CRUCES',
       u'PEDRO MORALES CERVANTES', u'PRAXAIR MEXICO, S. DE R.L. DE C.V.',
       u'RAUL GARCIA DE LOS ANGELES',
       u'REFACCIONARIA Y SERVICIOS DEL NORTE, S',
       u'REMOLQUES Y CARROCERIAS CRUZ, S.A. DE',
       u'SERVICIOS TRACTOMOTRICES, S.A. DE C.V.',
       u'STOUGHTON REFACCIONES Y SERVICIO ME',
       u'TALLERES ZUBIRIA S.A. DE C.V.', u'TECNOMOTUM SA DE CV',
       u'TRAILERS Y EQUIPO ALIADO, S.A. DE C.V.',
       u'TRANSPORTADORA EGOBA S.A. DE C.V.',
       u'TRANSPORTES GARCIAS TRUCKING, S.A. DE',
       u'TRANSPORTES MONROY SCHIAVON S.A. DE', u'TRAYLFER S.A. C.V.',
       u'UTILITY TRAILERS DE MEXICO,  S.A.P.I.  DE',
       u'VALENTIN PATIÑO BARRIGA', u'VIOLETA MORA HERNANDEZ',
       u'ZAPATA CAMIONES, S.A. DE C.V.'])]

# %%
BIMBO[['ano-mes','Importe total']].groupby('ano-mes').mean()
# Out:
#          Importe total
# ano-mes
# 201602    92394.280000
# 201603     6314.460000
# 201605    22431.150000
# 201606    24915.640000
# 201608    15263.280000
# 201609     3016.000000
# 201610     2239.960000
# 201611     7110.220000
# 201612    20861.650909
# 201701    42386.523333
# 201702    26800.474286
# 201703    16206.746667
# 201704    18354.680000
# 201705    12467.680000
# 201706    31148.320000
# 201707     8364.760000
# 201708    18301.900000
# 201709    22057.578462
# 201710     9976.890000
# 201711    13445.290909
# 201712    14842.586667
# 201801     7906.173333
# 201802    22298.845714
# 201803    14067.320000
# 201804    16109.306667
# 201805    20597.540000
# 201806    12575.891429
# 201807    15304.170000
# 201808     9924.090000
# 201809    23757.960000
# 201810    14963.072000
# 201811    18409.973333
# 201812     8638.520000
# 201901    16837.632000
# 201902    25045.560000
# 201903     3567.000000
# 201904    29531.280000
# 201905    11815.594286
# ...
